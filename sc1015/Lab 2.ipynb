# %% [markdown]
# # Housing Prices Exploratory Data Analysis
# Data science task: predict numeric house price given house features.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Problem 1: Data Preparation

# %% [markdown]
# Read dataset as dataframe:

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# Data types
# - **Numeric**: `float64`, `int64`
# - **Categorical**: `object`

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %% [markdown]
# Dataframe with only `int64` columns:

# %%
int_df = df.select_dtypes(include=np.int64)
int_df.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0         706           0        150          856       856       854
# 1         978           0        284         1262      1262         0
# 2         486           0        434          920       920       866
# 3         216           0        540          756       961       756
# 4         655           0        490         1145      1145      1053
#
# ...

# %% [markdown]
# Dataframe with only numeric columns. Here the definition for numeric is more stringent, columns with 'numeric' levels are not considered to be numeric.

# %%
numeric_df = df.select_dtypes(include=[np.int_, np.float_]).drop(columns=[
    "Id", "MSSubClass", "OverallQual", "OverallCond",
# ])
numeric_df.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## Problem 2: Statistical Summary

# %%
numeric_df["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
numeric_df["LotArea"].describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
numeric_df["LotArea"].hist()
# Out:
# <Axes: >

# %%
numeric_df[["LotArea"]].boxplot(vert=False)
# Out:
# <Axes: >

# %%
numeric_df["LotArea"].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
sns.jointplot(numeric_df, x="SalePrice", y="LotArea")

# %%
numeric_df[["LotArea", "SalePrice"]].corr()
# Out:
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000
